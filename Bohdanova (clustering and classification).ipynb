# %%
# Data preprocessing  
#importing the libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#importing the dataset
data = pd.read_csv('data.csv', header=None)

# %%
#rename columns
d = data.copy()
d.columns = ["q{}".format(i+1) for i in range(len(d.columns))]
columns_real = ["q309", "q311", "q319", "q24", "q298", "q165", "q25", "q2", "q62"] #"q119"]
names = {
    "q309": "Sex", "q165": "Religion",
    "q311": "Age", "q319": "Education",
    "q24": "Satisfaction_with_life",
    "q25": "Interpersonal_trust",
    "q298": "Employment_status",
    "q2": "Country",
    "q62": "Satisfaction_with_financial_situation_of_household",
    #"q119": "Trust_the_government"
}
columns_real_new = [names.get(x, x) for x in columns_real]
d = d[columns_real]
d = d.rename(columns=names)
d.describe()
# Out:
#                 Sex           Age     Education  Satisfaction_with_life  \
# count  90350.000000  90350.000000  90349.000000            90350.000000
# mean       1.514388     41.964361      5.569392                6.775695
# std        0.524561     16.583474      2.571788                2.362439
# min       -5.000000     -5.000000     -5.000000               -5.000000
# 25%        1.000000     28.000000      4.000000                5.000000
# 50%        2.000000     40.000000      6.000000                7.000000
# 75%        2.000000     54.000000      8.000000                8.000000
# max        2.000000     99.000000      9.000000               10.000000
#
#        Employment_status       Religion  Interpersonal_trust      Country  \
# count       90350.000000   90350.000000         90350.000000  90350.00000
# mean            3.273536    5531.439823             1.668866    467.39803
# std             2.300889   60360.296109             0.652453    248.45177
# min            -5.000000      -5.000000            -5.000000     12.00000
# 25%             1.000000       6.000000             1.000000    276.00000
# 50%             3.000000      49.000000             2.000000    434.00000
# 75%             5.000000      62.000000             2.000000    702.00000
# max             8.000000  710002.000000             2.000000    887.00000
#
#        Satisfaction_with_financial_situation_of_household
# count                                       90350.000000
# mean                                            5.877643
# std                                             2.527539
# min                                            -5.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             8.000000
# max                                            10.000000

# %%
#removing missing values (less than -1)
d = d.dropna()
for column in columns_real_new:
     d = d[d[column] > -1]
d["Religion"] = d["Religion"].apply(lambda x: 1 if x > 0 else x)
d = d.query("Employment_status < 8")
d["Employment_status"] = d["Employment_status"].apply(lambda x: d.get(x, x))
d.describe()
# Out:
#                 Sex           Age     Education  Satisfaction_with_life  \
# count  77345.000000  77345.000000  77345.000000            77345.000000
# mean       1.521598     42.031056      5.682733                6.859603
# std        0.499537     16.518564      2.399128                2.251782
# min        1.000000     16.000000      1.000000                1.000000
# 25%        1.000000     28.000000      4.000000                5.000000
# 50%        2.000000     40.000000      6.000000                7.000000
# 75%        2.000000     54.000000      8.000000                8.000000
# max        2.000000     99.000000      9.000000               10.000000
#
#        Employment_status      Religion  Interpersonal_trust       Country  \
# count       77345.000000  77345.000000         77345.000000  77345.000000
# mean            3.302347      0.811688             1.752680    474.087233
# std             2.063636      0.390964             0.431457    242.385822
# min             1.000000      0.000000             1.000000     12.000000
# 25%             1.000000      1.000000             2.000000    276.000000
# 50%             3.000000      1.000000             2.000000    458.000000
# 75%             5.000000      1.000000             2.000000    702.000000
# max             7.000000      1.000000             2.000000    887.000000
#
#        Satisfaction_with_financial_situation_of_household
# count                                       77345.000000
# mean                                            5.905708
# std                                             2.447392
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             8.000000
# max                                            10.000000

# %%
d.shape
# Out:
# (77345, 9)

# %%
import re
d = d[d["Employment_status"] < 8]
d["Employment_status"] = d["Employment_status"].apply(lambda x: 1 if x < 4 else 0)
d.describe()
# Out:
#                 Sex           Age     Education  Satisfaction_with_life  \
# count  77345.000000  77345.000000  77345.000000            77345.000000
# mean       1.521598     42.031056      5.682733                6.859603
# std        0.499537     16.518564      2.399128                2.251782
# min        1.000000     16.000000      1.000000                1.000000
# 25%        1.000000     28.000000      4.000000                5.000000
# 50%        2.000000     40.000000      6.000000                7.000000
# 75%        2.000000     54.000000      8.000000                8.000000
# max        2.000000     99.000000      9.000000               10.000000
#
#        Employment_status      Religion  Interpersonal_trust       Country  \
# count       77345.000000  77345.000000         77345.000000  77345.000000
# mean            0.547948      0.811688             1.752680    474.087233
# std             0.497699      0.390964             0.431457    242.385822
# min             0.000000      0.000000             1.000000     12.000000
# 25%             0.000000      1.000000             2.000000    276.000000
# 50%             1.000000      1.000000             2.000000    458.000000
# 75%             1.000000      1.000000             2.000000    702.000000
# max             1.000000      1.000000             2.000000    887.000000
#
#        Satisfaction_with_financial_situation_of_household
# count                                       77345.000000
# mean                                            5.905708
# std                                             2.447392
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             8.000000
# max                                            10.000000

# %%
#defining countries 
countries = """
     -5 'Missing; Unknown'
     -4 'Not asked in survey'
     -3 'Not applicable'
     -2 'No answer'
     -1 'Don't know'
     4 'Afghanistan'
     8 'Albania'
     12 'Algeria'
     16 'American Samoa'
     20 'Andorra'
     24 'Angola'
     28 'Antigua'
     31 'Azerbaijan'
     32 'Argentina'
     36 'Australia'
     40 'Austria'
     48 'Bahrain'
     50 'Bangladesh'
     51 'Armenia'
     52 'Barbados'
     56 'Belgium'
     60 'Bermuda'
     64 'Bhutan'
     68 'Bolivia'
     70 'Bosnia Herzegovina'
     72 'Botswana'
     76 'Brazil'
     84 'Belize'
     100 'Bulgaria'
     101 'SrpSka Republic'
     104 'Myanmar'
     108 'Burundi'
     112 'Belarus'
     116 'Cambodia'
     120 'Cameroon'
     124 'Canada'
     132 'Cape Verde'
     144 'Sri Lanka'
     148 'Chad'
     152 'Chile'
     156 'China'
     158 'Taiwan'
     170 'Colombia'
     180 'D.R. Congo'
     184 'Cook Islands'
     188 'Costa Rica'
     191 'Croatia'
     192 'Cuba'
     196 'Cyprus'
     197 'Cyprus (T)'
     203 'Czech Rep.'
     204 'Benin'
     208 'Denmark'
     214 'Dominican Rep.'
     218 'Ecuador'
     222 'El Salvador'
     226 'Eq.Guinea'
     231 'Ethiopia'
     232 'Eritrea'
     233 'Estonia'
     246 'Finland'
     250 'France'
     268 'Georgia'
     270 'Gambia'
     275 'Palestine'
     276 'Germany'
     288 'Ghana'
     292 'Gibraltar'
     300 'Greece'
     320 'Guatemala'
     324 'Guinea'
     328 'Guyana'
     332 'Haiti'
     340 'Honduras'
     344 'Hong Kong'
     348 'Hungary'
     352 'Iceland'
     356 'India'
     360 'Indonesia'
     364 'Iran'
     368 'Iraq'
     372 'Ireland'
     376 'Israel'
     380 'Italy'
     384 'Côte d'Ivoire'
     388 'Jamaica'
     392 'Japan'
     398 'Kazakhstan'
     400 'Jordan'
     404 'Kenya'
     408 'North Korea'
     410 'South Korea'
     414 'Kuwait'
     417 'Kyrgyzstan'
     418 'Laos'
     422 'Lebanon'
     426 'Lesotho'
     428 'Latvia'
     430 'Liberia'
     434 'Libya'
     438 'Liechtenstein'
     440 'Lithuania'
     442 'Luxembourg'
     450 'Madagascar'
     454 'Malawi'
     458 'Malaysia'
     466 'Mali'
     470 'Malta'
     474 'Martinique'
     478 'Mauritania'
     480 'Mauritius'
     484 'Mexico'
     492 'Monaco'
     496 'Mongolia'
     498 'Moldova'
     499 'Montenegro'
     504 'Morocco'
     508 'Mozambique'
     512 'Oman'
     516 'Namibia'
     524 'Nepal'
     528 'Netherlands'
     554 'New Zealand'
     558 'Nicaragua'
     562 'Niger'
     566 'Nigeria'
     578 'Norway'
     586 'Pakistan'
     591 'Panama'
     598 'Papua New Guinea'
     600 'Paraguay'
     604 'Peru'
     608 'Philippines'
     616 'Poland'
     620 'Portugal'
     624 'Guinea-Bissau'
     626 'Timor-Leste'
     630 'Puerto Rico'
     634 'Qatar'
     642 'Romania'
     643 'Russia'
     646 'Rwanda'
     682 'Saudi Arabia'
     686 'Senegal'
     688 'Serbia'
     690 'Seychelles'
     694 'Sierra Leone'
     702 'Singapore'
     703 'Slovakia'
     704 'Viet Nam'
     705 'Slovenia'
     706 'Somalia'
     710 'South Africa'
     716 'Zimbabwe'
     724 'Spain'
     736 'Sudan'
     740 'Suriname'
     748 'Swaziland'
     752 'Sweden'
     756 'Switzerland'
     760 'Syria'
     762 'Tajikistan'
     764 'Thailand'
     768 'Togo'
     780 'Trinidad and Tobago'
     784 'United Arab Emirates'
     788 'Tunisia'
     792 'Turkey'
     795 'Turkmenistan'
     800 'Uganda'
     804 'Ukraine'
     807 'Macedonia'
     818 'Egypt'
     826 'United Kingdom'
     834 'Tanzania'
     840 'United States'
     850 'U.S. Virgin Islands'
     854 'Burkina Faso'
     858 'Uruguay'
     860 'Uzbekistan'
     862 'Venezuela'
     887 'Yemen'
     891 'Serbia and Montenegro'
     894 'Zambia'
     900 'West Germany'
     901 'East Germany'
     902 'Tambov'
     903 'Moscow'
     904 'Basque Country'
     906 'Andalusia'
     907 'Galicia'
     908 'Great Britain'
     909 'North Ireland'
     910 'Valencia'
     911 'Serbia'
     912 'Montenegro'
     913 'Serbian Bosnia'
     914 'Bosnia'
     915 'Kosovo'
     916 'Flanders-Belgium'
     917 'Israel (Jews)'
     918 'Israel (Arabs)'
"""

# %%
#convert country string into a dictionary
import re
countries = countries.split('\n')
countries = [x.strip() for x in countries if x]
country_re = r"([\-]{0,1}[0-9]+)[ ]*\'(.*)\'"
countries = [re.findall(country_re, x)[0] for x in countries]
countries = {int(k): v for k, v in countries}

# %%
#definig regions
africa = """Burundi
Comoros
Djibouti
Eritrea
Libya
Ethiopia
Kenya
Cook Islands
Madagascar
Malawi
Mauritius
Mayotte
Mozambique
Reunion
Rwanda
Seychelles
Somalia
Tanzania, United Republic of
Uganda
Zambia
Zimbabwe
Angola
Cameroon
Central African Republic
Chad
Congo
D.R. Congo
Eq.Guinea
Gabon
Sao Tome and Principe
Algeria
Egypt
Libyan Arab Jamahiriya
Morroco
Côte d'Ivoire
South Sudan
Sudan
Tunisia
Western Sahara
Botswana
Eswatini
Lesotho
Namibia
South Africa
Benin
Burkina Faso
Cape Verde
Cote d'Ivoire
Gambia
Ghana
Guinea
Guinea-Bissau
Liberia
Mali
Mauritania
Niger
Nigeria
Tanzania
Morocco
Saint Helena
Senegal
Sierra Leone
Swaziland
Togo""".split("\n")
africa
carribean = """Anguilla
Antigua
Aruba
Bahamas
Barbados
Bonaire, Saint Eustatius and Saba
British Virgin Islands
Cayman Islands
Cuba
Curaçao
Dominica
Dominican Rep.
Grenada
Guadeloupe
Haiti
Jamaica
U.S. Virgin Islands
Martinique
Monserrat
Puerto Rico
Saint-Barthélemy
St. Kitts and Nevis
Saint Lucia
Saint Martin
Saint Vincent and the Grenadines
Sint Maarten
Trinidad and Tobago
Turks and Caicos Islands
Virgin Islands""".split("\n")
carribean
camerica = """Belize
Costa Rica
El Salvador
Guatemala
Honduras
Mexico
Nicaragua
Panama""".split("\n")
camerica
samerica = """Argentina
Bolivia
Brazil
Chile
Colombia
Ecuador
Falkland Islands
French Guiana
Guyana
Paraguay
Peru
Suriname
Uruguay
Venezuela""".split("\n")
samerica
namerica = """Bermuda
Canada
Greenland
Saint Pierre and Miquelon
United States""".split("\n")
namerica
asia = """Afghanistan
Armenia
Azerbaijan
Bangladesh
Bhutan
Brunei Darussalam
Cambodia
China
Georgia
Hong Kong
India
Indonesia
Japan
Kazakhstan
North Korea
South Korea
Kyrgyzstan
Laos
Macao
Malaysia
Maldives
Mongolia
Myanmar
Nepal
Pakistan
Phillipines
Philippines
Singapore
Sri Lanka
Taiwan
Timor-Leste
Tajikistan
Thailand
Timor Leste
Turkmenistan
Viet Nam
Uzbekistan
Vietnam """.split("\n")
asia
europe = """Albania
Andorra
Belarus
Bosnia Herzegovina
Bosnia
Croatia
Faroe Islands
Gibraltar
Guerney and Alderney
Iceland
Jersey
North Ireland
Kosovo
Liechtenstein
Man, Island of
Moldova
Monaco
Montenegro
North Macedonia
Norway
Russia
San Marino
SrpSka Republic
Serbia
Svalbard and Jan Mayen Islands
Switzerland
Turkey
Ukraine
United Kingdom
Vatican City State
Austria
Belgium
Bulgaria
Cyprus
Cyprus (T)
Czech Rep.
Denmark
Estonia
Finland
France
Germany
West Germany
East Germany
Greece
Hungary
Ireland
Italy
Latvia
Lithuania
Luxembourg
Malta
Netherlands
Macedonia
Poland
Portugal
Great Britain
Romania
Slovakia
Slovenia
Serbia and Montenegro
Spain
Valencia
Galicia
Andalusia
Flanders-Belgium
Basque Country
Serbian Bosnia
Tambov
Moscow
Sweden""".split("\n")
europe
mideast = """Bahrain
Iraq
Iran
Israel (Jews)
Israel (Arabs)
Israel
Jordan
Kuwait
Lebanon
Oman
Palestine
Qatar
Saudi Arabia
Syria
United Arab Emirates
Yemen""".split("\n")
mideast
oceania = """Australia
Fiji
French Polynesia
Guam
Kiribati
Marshall Islands
Micronesia
New Caledonia
New Zealand
Papua New Guinea
Samoa
American Samoa
Solomon, Islands
Tonga
Vanuatu""".split("\n")
oceania
regions = {'Africa': africa, 'Carribean': carribean, 'Central America': camerica, 'South America': samerica, 'Northern America': namerica, 'Asia': asia, 'Europe': europe, 'Middle East': mideast, 'Oceania': oceania}

# %%
#adding region column
country_to_region = {
    c: r
    for r, c_l in regions.items()
    for c in c_l
}
int_country_to_region = {k: f"Country_{country_to_region.get(c)}" for k, c in countries.items()}
d["Region"] = d["Country"].apply(int_country_to_region.get)
d.describe()
# Out:
#                 Sex           Age     Education  Satisfaction_with_life  \
# count  77345.000000  77345.000000  77345.000000            77345.000000
# mean       1.521598     42.031056      5.682733                6.859603
# std        0.499537     16.518564      2.399128                2.251782
# min        1.000000     16.000000      1.000000                1.000000
# 25%        1.000000     28.000000      4.000000                5.000000
# 50%        2.000000     40.000000      6.000000                7.000000
# 75%        2.000000     54.000000      8.000000                8.000000
# max        2.000000     99.000000      9.000000               10.000000
#
#        Employment_status      Religion  Interpersonal_trust       Country  \
# count       77345.000000  77345.000000         77345.000000  77345.000000
# mean            0.547948      0.811688             1.752680    474.087233
# std             0.497699      0.390964             0.431457    242.385822
# min             0.000000      0.000000             1.000000     12.000000
# 25%             0.000000      1.000000             2.000000    276.000000
# 50%             1.000000      1.000000             2.000000    458.000000
# 75%             1.000000      1.000000             2.000000    702.000000
# max             1.000000      1.000000             2.000000    887.000000
#
#        Satisfaction_with_financial_situation_of_household
# count                                       77345.000000
# mean                                            5.905708
# std                                             2.447392
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             8.000000
# max                                            10.000000

# %%
#transforming region into wide format
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
reg_encoded = enc.fit_transform(d[["Region"]])
reg_encoded = pd.DataFrame(
    reg_encoded.toarray(),
    columns=enc.categories_[0]
)
d2 = pd.concat([d.reset_index(), reg_encoded], axis=1)

d2 = d2.drop(columns=["Country", "Region", "index"])

# %%
d2["Interpersonal_trust"] = d2["Interpersonal_trust"].apply(lambda x: 0 if x == 2 else x)
# 2 is "don;t trust", then remap to 0 is don't trust and 1 is trust
d2["Sex"] = d2["Sex"].apply(lambda x: 0 if x == 2 else x)
# Set Female to 0, Male to 1
d2.describe()
# Out:
#                 Sex           Age     Education  Satisfaction_with_life  \
# count  77345.000000  77345.000000  77345.000000            77345.000000
# mean       0.478402     42.031056      5.682733                6.859603
# std        0.499537     16.518564      2.399128                2.251782
# min        0.000000     16.000000      1.000000                1.000000
# 25%        0.000000     28.000000      4.000000                5.000000
# 50%        0.000000     40.000000      6.000000                7.000000
# 75%        1.000000     54.000000      8.000000                8.000000
# max        1.000000     99.000000      9.000000               10.000000
#
#        Employment_status      Religion  Interpersonal_trust  \
# count       77345.000000  77345.000000         77345.000000
# mean            0.547948      0.811688             0.247320
# std             0.497699      0.390964             0.431457
# min             0.000000      0.000000             0.000000
# 25%             0.000000      1.000000             0.000000
# 50%             1.000000      1.000000             0.000000
# 75%             1.000000      1.000000             0.000000
# max             1.000000      1.000000             1.000000
#
#        Satisfaction_with_financial_situation_of_household  Country_Africa  \
# count                                       77345.000000     77345.000000
# mean                                            5.905708         0.188790
# std                                             2.447392         0.391345
# min                                             1.000000         0.000000
# 25%                                             4.000000         0.000000
# 50%                                             6.000000         0.000000
# 75%                                             8.000000         0.000000
# max                                            10.000000         1.000000
#
#        Country_Asia  Country_Carribean  Country_Central America  \
# count  77345.000000       77345.000000             77345.000000
# mean       0.332368           0.012567                 0.025509
# std        0.471065           0.111397                 0.157666
# min        0.000000           0.000000                 0.000000
# 25%        0.000000           0.000000                 0.000000
# 50%        0.000000           0.000000                 0.000000
# 75%        1.000000           0.000000                 0.000000
# max        1.000000           1.000000                 1.000000
#
#        Country_Europe  Country_Middle East  Country_Northern America  \
# count    77345.000000         77345.000000              77345.000000
# mean         0.234909             0.066262                  0.026711
# std          0.423944             0.248740                  0.161240
# min          0.000000             0.000000                  0.000000
# 25%          0.000000             0.000000                  0.000000
# 50%          0.000000             0.000000                  0.000000
# 75%          0.000000             0.000000                  0.000000
# max          1.000000             1.000000                  1.000000
#
#        Country_Oceania  Country_South America
# count     77345.000000           77345.000000
# mean          0.022419               0.090465
# std           0.148043               0.286848
# min           0.000000               0.000000
# 25%           0.000000               0.000000
# 50%           0.000000               0.000000
# 75%           0.000000               0.000000
# max           1.000000               1.000000

# %%
#from pandas_profiling import ProfileReport
#profile = ProfileReport(d5, title='Data Report', explorative=True)
#profile.to_file('report_detailed.html')

# %%
# Age distribution
d2['Age'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Sex distribution
d2['Sex'].plot(kind = 'hist', bins=8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Education distribution
d2['Education'].plot(kind = 'hist', bins=8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Satisfaction_with_life distribution
d2['Satisfaction_with_life'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Employment_status distribution
#d2['Employment_status'].plot(kind = 'hist', bins=8)

# %%
#Religion distribution
d['Religion'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Satisfaction_with_financial_situation_of_household distribution
d['Satisfaction_with_financial_situation_of_household'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Interpersonal_trust distribution
d['Interpersonal_trust'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Logistic regression

# %%
#Splitting the dataset into the Training set and Test set
X = d2[[c for c in d2.columns if c != "Interpersonal_trust"]]
y = d2["Interpersonal_trust"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler().fit(X_train)
X_train = sc_X.transform(X_train)
X_test = sc_X.transform(X_test)

# %%
d2[[c for c in d2.columns if c != "Interpersonal_trust"]].columns
# Out:
# Index(['Sex', 'Age', 'Education', 'Satisfaction_with_life',
#        'Employment_status', 'Religion',
#        'Satisfaction_with_financial_situation_of_household', 'Country_Africa',
#        'Country_Asia', 'Country_Carribean', 'Country_Central America',
#        'Country_Europe', 'Country_Middle East', 'Country_Northern America',
#        'Country_Oceania', 'Country_South America'],
#       dtype='object')

# %%
X_train1 =X_train
X_test1 =X_test

# %%
X_train
# Out:
# array([[ 1.04327842,  0.35906635, -0.28435509, ..., -0.16731473,
#         -0.15081048, -0.3160394 ],
#        [ 1.04327842,  2.11281603,  0.54831595, ..., -0.16731473,
#         -0.15081048, -0.3160394 ],
#        [-0.9585169 , -0.48757143,  1.38098699, ..., -0.16731473,
#         -0.15081048, -0.3160394 ],
#        ...,
#        [ 1.04327842, -0.66899381, -0.28435509, ..., -0.16731473,
#         -0.15081048, -0.3160394 ],
#        [ 1.04327842, -0.48757143, -1.94969716, ..., -0.16731473,
#         -0.15081048, -0.3160394 ],
#        [ 1.04327842,  0.4800146 , -0.7006906 , ..., -0.16731473,
#         -0.15081048, -0.3160394 ]])

# %%
pd.Series(X_train[:,6]).value_counts()
# Out:
# -0.692133    41835
#  1.444808    20041
# dtype: int64

# %%
import statsmodels.api as sm
lr = sm.Logit(y_train,X_train).fit(method='newton', maxiter=200)

print(lr.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.661394
#          Iterations 6
#                            Results: Logit
# ====================================================================
# Model:              Logit               Pseudo R-squared: -0.185
# Dependent Variable: Interpersonal_trust AIC:              81878.8087
# Date:               2021-03-10 11:10    BIC:              82014.3020
# No. Observations:   61876               Log-Likelihood:   -40924.
# Df Model:           14                  LL-Null:          -34523.
# Df Residuals:       61861               LLR p-value:      1.0000
# Converged:          1.0000              Scale:            1.0000
# No. Iterations:     6.0000
# --------------------------------------------------------------------
#          Coef.    Std.Err.     z     P>|z|     [0.025       0.975]
# --------------------------------------------------------------------
# x1      -0.0091      0.0085  -1.0617 0.2884      -0.0258      0.0077
# x2       0.0815      0.0090   9.0472 0.0000       0.0638      0.0992
# x3       0.0932      0.0090  10.4143 0.0000       0.0757      0.1108
# x4       0.0767      0.0096   8.0085 0.0000       0.0579      0.0955
# x5       0.0462      0.0087   5.3028 0.0000       0.0291      0.0633
# x6      -0.2254      0.0088 -25.7465 0.0000      -0.2425     -0.2082
# x7       0.1219      0.0095  12.8862 0.0000       0.1034      0.1405
# x8      -0.0947 153150.2340  -0.0000 1.0000 -300169.0376 300168.8482
# x9       0.0735 184173.9902   0.0000 1.0000 -360974.3141 360974.4612
# x10     -0.0958  44171.6071  -0.0000 1.0000  -86574.8549  86574.6633
# x11     -0.0935  61392.9284  -0.0000 1.0000 -120328.0221 120327.8351
# x12      0.0944 165434.4612   0.0000 1.0000 -324245.4915 324245.6802
# x13      0.0351  97390.8366   0.0000 1.0000 -190882.4971 190882.5673
# x14      0.0568  63639.7765   0.0000 1.0000 -124731.6131 124731.7268
# x15      0.2113  57656.7048   0.0000 1.0000 -113004.8537 113005.2763
# x16     -0.2127 112351.9759  -0.0000 1.0000 -220206.0390 220205.6136
# ====================================================================

# %%
# Features selection
X_train1 = X_train1[:,[1,2,3,4,5,6]]
X_test1 = X_test1[:,[1,2,3,4,5,6]]

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression(
    random_state=68, 
    solver='saga'
#    class_weight='balanced',
#    penalty='l1', solver='liblinear'
).fit(X_train1, y_train)

# %%
# Predicting the Test set results
y_pred = reg.predict(X_test1)
reg.score(X_test1,y_test)
# Out:
# 0.7553170857844722

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[11320   244]
#  [ 3541   364]]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_score = reg.predict_proba(X_test1)[:,1]
tpr, fpr,  thresh = roc_curve(y_test, y_score)
from matplotlib import pyplot as plt
plt.scatter(tpr, fpr)
roc_auc_score(y_test, y_score)
print(thresh)
print(fpr)
# Out:
# [1.79843698 0.79843698 0.78501602 ... 0.03430149 0.03414734 0.01587015]
# [0.00000000e+00 0.00000000e+00 2.56081946e-04 ... 9.99743918e-01
#  1.00000000e+00 1.00000000e+00]

# %%
def predict_thresh(clf, x, thresh):
    y_prob = clf.predict_proba(x)
    y_prob = y_prob[:,1]
    y_tst = np.array([d>thresh for d in y_prob])
    return y_tst

# %%
from sklearn.metrics import classification_report
threshold = 0.4
print(classification_report(y_train, predict_thresh(reg, X_train1, threshold)))
print(classification_report(y_test, predict_thresh(reg, X_test1, threshold)))
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict_thresh(reg, X_test1, threshold))
print(cm)
print(reg.score(X_train1, y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85     46652
#            1       0.52      0.25      0.33     15224
#
#     accuracy                           0.76     61876
#    macro avg       0.65      0.59      0.59     61876
# weighted avg       0.72      0.76      0.72     61876
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.85     11564
#            1       0.52      0.25      0.34      3905
#
#     accuracy                           0.75     15469
#    macro avg       0.65      0.59      0.59     15469
# weighted avg       0.72      0.75      0.72     15469
#
# [[10668   896]
#  [ 2922   983]]
# 0.7619917253862564

# %%
from sklearn.metrics import accuracy_score
thresholds = np.arange(0,1,0.01)
accs = [accuracy_score(y_train, predict_thresh(reg, X_train1, thresgold)) for thresgold in thresholds]
plt.scatter(thresholds, accs)

# %%
print(max(accs))
print(max(thresholds, key=lambda x: accs[list(thresholds).index(x)]))
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict_thresh(reg, X_test2, threshold))
print(cm)
print(reg.score(X_train1, y_train))
# Out:
# 0.7644644126963605
# 0.47000000000000003
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-126a9a4f8cc8> in <module>
#       3 # Making the Confusion Matrix
#       4 from sklearn.metrics import confusion_matrix
# ----> 5 cm = confusion_matrix(y_test, predict_thresh(reg, X_test2, threshold))
#       6 print(cm)
#       7 print(reg.score(X_train1, y_train))
#
# NameError: name 'X_test2' is not defined

# %%
#estimator = LogisticRegression(class_weight='balanced', penalty='l1', solver='liblinear')
#selector = RFE(estimator, n_features_to_select=5, step=1)
#selector = selector.fit(X_train, y_train)
#selector.support_

# %%
#cols = [c for c in d2.columns if c != 'Interpersonal_trust']
#dc = dict(enumerate(selector.support_))
#dc = {k: v for k, v in dc.items() if v}
#features = []
#for i in dc:
    #features.append(cols[i])
#features

# %%
#Балансирование кластеров (отсечение избыточных кластеров в тренировочной выборке)

# %%
from itertools import groupby

# %%
for cl, group in groupby(sorted(y_train)):
    print(cl, len(list(group)))

# %%
y_train.index = range(y_train.shape[0])

# %%
y_train_1 = y_train[y_train == 1]
X_train_1 = X_train[y_train_1.index,:]

# %%
from numpy.random import choice
y_train_0 = y_train[y_train == 0]
y_train_0 = y_train_0.sample(n=y_train_1.shape[0], replace=False)
X_train_0 = X_train[y_train_0.index,:]
X_train_0.shape

# %%
X_train_0

# %%
from numpy import concatenate
X_train_01 = concatenate([X_train_0, X_train_1])
y_train_01 = concatenate([y_train_0, y_train_1])

# %%
import statsmodels.api as sm
lr = sm.Logit(y_train_01,X_train_01).fit(method='newton', maxiter=2000)

print(lr.summary2())

# %%
X_train2 =X_train_01[:,[1,2,3,4,5,6]]
X_test2 =X_test[:,[1,2,3,4,5,6]]

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression(
    random_state=68, 
    solver='saga'
#    class_weight='balanced',
#    penalty='l1', solver='liblinear'
).fit(X_train2, y_train_01)

# %%
# Predicting the Test set results
y_pred = reg.predict(X_test2)
reg.score(X_test2,y_test)

# %%
from sklearn.metrics import classification_report
threshold = 0.4
print(classification_report(y_train_01, predict_thresh(reg, X_train2, threshold)))
print(classification_report(y_test, predict_thresh(reg, X_test2, threshold)))
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict_thresh(reg, X_test2, threshold))
print(cm)
print(reg.score(X_train2, y_train_01))

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_score = reg.predict_proba(X_test2)[:,1]
tpr, fpr,  thresh = roc_curve(y_test, y_score)
from matplotlib import pyplot as plt
plt.scatter(tpr, fpr)
print(roc_auc_score(y_test, y_score))
print(thresh)
print(fpr)

# %%
from sklearn.metrics import accuracy_score
thresholds = np.arange(0,1,0.01)
accs = [accuracy_score(y_test, predict_thresh(reg, X_test2, thresgold)) for thresgold in thresholds]
plt.scatter(thresholds, accs)

# %%
print(max(accs))
print(max(thresholds, key=lambda x: accs[list(thresholds).index(x)]))

# %%
from sklearn.metrics import classification_report
threshold = 0.71
print(classification_report(y_train_01, predict_thresh(reg, X_train2, threshold)))
print(classification_report(y_test, predict_thresh(reg, X_test2, threshold)))
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict_thresh(reg, X_test2, threshold))
print(cm)

# %%
# Support Vector Machine (SVM)

# %%
# Fitting SVM to the Training set 
from sklearn.svm import SVC
svm = SVC(kernel = 'rbf', random_state = 10).fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = svm.predict(X_test)
svm.score(X_test,y_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
# SVM, используя сбалансированную тренировочную выборку

# %%
# Fitting SVM to the Training set 
from sklearn.svm import SVC
svm01 = SVC(kernel = 'rbf', random_state = 10).fit(X_train_01, y_train_01)

# %%
# Predicting the Test set results
y_pred = svm01.predict(X_test)
svm01.score(X_test,y_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
# K-Nearest Neighbors (K-NN)

# %%
# Optimal K 
from sklearn.neighbors import KNeighborsClassifier
error_rate = []
for i in range(1,50):
     knn = KNeighborsClassifier(n_neighbors=i)
     knn.fit(X_train,y_train)
     pred_i = knn.predict(X_test)
     error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,50),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-1a227f3ead29> in <module>
#       4 for i in range(1,50):
#       5      knn = KNeighborsClassifier(n_neighbors=i)
# ----> 6      knn.fit(X_train,y_train)
#       7      pred_i = knn.predict(X_test)
#       8      error_rate.append(np.mean(pred_i != y_test))
#
# c:\users\masta\miniconda3\envs\data_analysis\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1155             self._y = self._y.ravel()
#    1156
# -> 1157         return self._fit(X)
#    1158
#    1159     def _more_tags(self):
#
# c:\users\masta\miniconda3\envs\data_analysis\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X)
#     456             self._tree = KDTree(X, self.leaf_size,
#     457                                 metric=self.effective_metric_,
# --> 458                                 **self.effective_metric_params_)
#     459         elif self._fit_method == 'brute':
#     460             self._tree = None
#
# KeyboardInterrupt:

# %%
# Fitting K-NN to the Training set
knn = KNeighborsClassifier(n_neighbors = 47, metric = 'minkowski', p = 2).fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = knn.predict(X_test)
knn.score(X_test,y_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
# Naive Bayes

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB().fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = nb.predict(X_test)
nb.score(X_test,y_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
# Naive Bayes, используя сбалансированную тренировочную выборку

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB().fit(X_train_01, y_train_01)

# %%
# Predicting the Test set results
y_pred = nb.predict(X_test)
nb.score(X_test,y_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# %%
# K-Means Clustering

# %%
#rename columns
#d3 = data.copy()
#d3.columns = ["q{}".format(i+1) for i in range(len(d3.columns))]
#columns_real = ["q309", "q311", "q319", "q24", "q298", "q165", "q25", "q62"] 
#names = {
#    "q309": "Sex", "q165": "Religion",
 #   "q311": "Age", "q319": "Education",
  #  "q24": "Satisfaction_with_life",
   # "q25": "Interpersonal_trust",
    #"q298": "Employment_status",
#    "q62": "Satisfaction_with_financial_situation_of_household",
#}
#columns_real_new = [names.get(x, x) for x in columns_real]
#d3 = d3[columns_real]
#d3 = d3.rename(columns=names)
#d3.describe()

# %%
#removing missing values (less than -1)
#d3 = d3.dropna()
#for column in columns_real_new:
#     d3 = d3[d3[column] > -1]
#d3["Religion"] = d3["Religion"].apply(lambda x: 1 if x > 0 else x)
#d3["Interpersonal_trust"] = d3["Interpersonal_trust"].apply(lambda x: 0 if x == 2 else x)
# 2 is "don;t trust", then remap to 0 is don't trust and 1 is trust
#d3["Sex"] = d3["Sex"].apply(lambda x: 0 if x == 2 else x)
# Set Female to 0, Male to 1
#d3.describe()

# %%
d3=d2[[c for c in d2.columns if not c.startswith("Country_")]]

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler().fit(d3)
d3 = sc.transform(d3)
pd.DataFrame(d3, columns = ['Sex','Age','Education','Satisfaction_with_life','Employment_status','Religion','Interpersonal_trust','Satisfaction_with_financial_situation_of_household']).round(2)
# Out:
#        Sex   Age  Education  Satisfaction_with_life  Employment_status  \
# 0      1.0  0.06       0.75                    0.78                0.0
# 1      0.0  0.10       0.75                    0.44                0.0
# 2      0.0  0.12       0.50                    0.33                1.0
# 3      0.0  0.14       0.62                    0.78                1.0
# 4      0.0  0.23       0.25                    0.78                1.0
# ...    ...   ...        ...                     ...                ...
# 77340  0.0  0.30       0.38                    0.00                0.0
# 77341  1.0  0.13       0.50                    0.00                0.0
# 77342  0.0  0.25       0.12                    0.33                0.0
# 77343  0.0  0.19       0.50                    0.00                0.0
# 77344  0.0  0.18       0.38                    0.44                0.0
#
#        Religion  Interpersonal_trust  \
# 0           1.0                  0.0
# 1           1.0                  1.0
# 2           1.0                  1.0
# 3           1.0                  0.0
# 4           1.0                  0.0
# ...         ...                  ...
# 77340       1.0                  0.0
# 77341       1.0                  1.0
# 77342       1.0                  0.0
# 77343       1.0                  0.0
# 77344       1.0                  0.0
#
#        Satisfaction_with_financial_situation_of_household
# 0                                                   1.00
# 1                                                   1.00
# 2                                                   0.56
# 3                                                   0.56
# 4                                                   0.33
# ...                                                  ...
# 77340                                               0.00
# 77341                                               0.00
# 77342                                               0.22
# 77343                                               0.00
# 77344                                               0.00
#
# [77345 rows x 8 columns]

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(d3)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Using the silhouette method to find the optimal number of clusters
from sklearn.metrics import silhouette_score

sil = []

for k in range(2, 15):
  kmeans = KMeans(n_clusters = k).fit(d3)  
  preds = kmeans.fit_predict(d3)
  sil.append(silhouette_score(d3, preds, metric = 'euclidean'))


plt.plot(range(2, 15), sil)
plt.title('Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('Sil')
plt.show()

for i in range(len(sil)):
 print(str(i+2) +":"+ str(sil[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f842d9f6a88> in <module>
#       5
#       6 for k in range(2, 15):
# ----> 7   kmeans = KMeans(n_clusters = k).fit(d3)
#       8   preds = kmeans.fit_predict(d3)
#       9   sil.append(silhouette_score(d3, preds, metric = 'euclidean'))
#
# NameError: name 'KMeans' is not defined

# %%
#локальный макисмум достигается при количестве кластеров = 4

# %%
# Fitting K-Means to the dataset
km = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0).fit_predict(d3)
kms = KMeans(n_clusters = 4, random_state = 0).fit(d3)
pd.DataFrame(kms.cluster_centers_, columns = ['Sex','Age','Education','Satisfaction_with_life','Employment_status','Religion','Interpersonal_trust','Satisfaction_with_financial_situation_of_household']).round(2)
# Out:
#    Sex   Age  Education  Satisfaction_with_life  Employment_status  Religion  \
# 0  1.0  0.29       0.61                    0.66                1.0      0.79
# 1  0.0  0.34       0.51                    0.64               -0.0      0.87
# 2  1.0  0.35       0.58                    0.63                0.0      0.80
# 3  0.0  0.29       0.65                    0.67                1.0      0.78
#
#    Interpersonal_trust  Satisfaction_with_financial_situation_of_household
# 0                 0.26                                               0.56
# 1                 0.22                                               0.53
# 2                 0.24                                               0.53
# 3                 0.28                                               0.56

# %%
# Less features
#X = d3[:, [0, 2, 4, 5, 6]]

# %%
# Fitting K-Means to the dataset
#km = KMeans(n_clusters = 6, init = 'k-means++', random_state = 0).fit_predict(X)
#kms = KMeans(n_clusters = 6, random_state = 0).fit(X)
#columns = ['Sex', 'Education', 'Employment_status','Religion', 'Interpersonal_trust', ]
#pd.DataFrame(kms.cluster_centers_, columns = columns).round(2)

# %%
# [0, 2, 4, 5, 6]
new_X = [
    kms.cluster_centers_[:,0],
    np.array([0 for i in range(kms.cluster_centers_.shape[0])]),
    kms.cluster_centers_[:,1],
    np.array([0 for i in range(kms.cluster_centers_.shape[0])]),
    *kms.cluster_centers_[:,2:-1].T,
    *[
        
    np.array([0 for i in range(kms.cluster_centers_.shape[0])])
        for _ in range(2)
    ]
]
# for i, el in enumerate(new_X):
#     print(i, el)
new_X = [np.reshape(el, (1, kms.cluster_centers_.shape[0])) for el in new_X]
new_X = np.concatenate(new_X)
new_X2 = pd.DataFrame(sc.inverse_transform(new_X.T), columns=['Sex','Age','Education','Satisfaction_with_life','Employment_status','Religion','Interpersonal_trust','Satisfaction_with_financial_situation_of_household'])
new_X2['Interpersonal_trust'] = kms.cluster_centers_[:,-1]
new_X2[columns].round(2)
